# %%
from PyPDF2 import PdfReader
from sentence_transformers import SentenceTransformer
from dotenv import load_dotenv,dotenv_values
import json

# %%
FILE_PATH = "C:/Ambarish/NCERT/CHAP04-BIOLOGY-CLASS11.pdf"

# %%
load_dotenv()
values_env = dotenv_values(".env")
MODEL_NAME = values_env['MODEL_NAME']

# %%
# Read the PDF file and return the text
def get_pdf_data(file_path, num_pages = 1):
    reader = PdfReader(file_path)
    full_doc_text = ""
    pages = reader.pages
    num_pages = len(pages) 
    
    try:
        for page in range(num_pages):
            current_page = reader.pages[page]
            text = current_page.extract_text()
            full_doc_text += text
    except:
        print("Error reading file")
    finally:
        return full_doc_text

# %%
# Divide the text into chunks of chunk_length 
# [ default is 500] characters
def get_chunks(fulltext:str,chunk_length =500) -> list:
    text = fulltext

    chunks = []
    while len(text) > chunk_length:
        last_period_index = text[:chunk_length].rfind('.')
        if last_period_index == -1:
            last_period_index = chunk_length
        chunks.append(text[:last_period_index])
        text = text[last_period_index+1:]
    chunks.append(text)

    return chunks

# %%
filename = FILE_PATH

# %%
full_doc_text = get_pdf_data(filename)

# %%
print(f'Full doc text length: {len(full_doc_text)}')
# Out:
# Full doc text length: 31802

# %%
Lines =get_chunks(full_doc_text,500)

# %%
len(Lines)
# Out:
# 73

# %%
type(Lines)
# Out:
# list

# %%
model = SentenceTransformer(MODEL_NAME)

# %%
embeddings_all = model.encode(Lines,show_progress_bar=True)
# Out:
# Batches: 100%|██████████| 3/3 [00:04<00:00,  1.35s/it]

# %%
len(embeddings_all)
# Out:
# 73

# %%
embeddings_all[4].tolist()[:5]
# Out:
# [0.03996901214122772,
#  -0.038540229201316833,
#  0.016151603311300278,
#  -0.028872955590486526,
#  -0.0932854413986206]

# %%
counter = 0

# %%
input_data = []

# %%
for line in Lines:
    d = {}
    d['id'] = str(counter)
    d['line'] = line
    d['embedding'] = embeddings_all[counter].tolist()
    counter = counter + 1
    input_data.append(d)

# %%
input_data[0]
# Out:
# {'id': '0',
#  'line': 'ANIMAL KINGDOM 3737\nWhen you look around, you will observe different animals with different\nstructures and forms.  As over a million species of animals have been\ndescribed till now, the need for classification becomes all the more\nimportant. The classification also helps in assigning a systematic position\nto newly described species.\n4',
#  'embedding': [-0.007113905157893896,
#   -0.03274315595626831,
#   0.04404618963599205,
#   -0.019613116979599,
#   0.005531826987862587,
#   -0.01970878429710865,
#   -0.09384632110595703,
#   -0.1018192321062088,
#   0.053117722272872925,
#   0.03509262204170227,
#   -0.010434729978442192,
#   -0.13946926593780518,
#   -0.05225949361920357,
#   0.04996480047702789,
#   -0.004872112534940243,
#   -0.021825173869729042,
#   -0.002666912507265806,
#   -0.008894842118024826,
#   -0.05013251304626465,
#   -0.028873901814222336,
#   0.049069397151470184,
#   0.031020402908325195,
#   -0.010344062931835651,
#   0.049582600593566895,
#   -0.1187777891755104,
#   -0.006269610952585936,
#   0.006886427756398916,
#   0.02911803312599659,
#   0.037132568657398224,
#   -0.1153155118227005,
#   -0.07455799728631973,
#   0.059816084802150726,
#   -0.019729647785425186,
#   -0.030226999893784523,
#   0.04122014343738556,
#   0.08770392835140228,
#   0.022109517827630043,
#   0.004585532005876303,
#   0.01841900497674942,
#   0.008819149807095528,
#   0.003720494918525219,
#   -0.058976951986551285,
#   0.0665593296289444,
#   0.04812062904238701,
#   -0.07192545384168625,
#   0.011463087052106857,
#   0.031511157751083374,
#   0.035947076976299286,
#   -0.0067540123127400875,
#   -0.019318310543894768,
#   0.01923830434679985,
#   0.12351499497890472,
#   -0.0645769014954567,
#   -0.030254799872636795,
#   -0.03671209514141083,
#   0.0020011975429952145,
#   0.03622189909219742,
#   -0.03405153751373291,
#   -0.02551889792084694,
#   -0.019849764183163643,
#   -0.0851564109325409,
#   -0.01230354979634285,
#   0.06429856270551682,
#   0.032486461102962494,
#   0.057627178728580475,
#   -0.07081500440835953,
#   0.04446806758642197,
#   0.010759063996374607,
#   0.00416586734354496,
#   -0.07022976875305176,
#   0.014575148932635784,
#   0.03441830351948738,
#   0.06485749781131744,
#   0.04269273206591606,
#   0.019320514053106308,
#   0.02468276023864746,
#   0.07171296328306198,
#   -0.03274323791265488,
#   0.010319456458091736,
#   -0.024928903207182884,
#   -0.007979240268468857,
#   0.055653948336839676,
#   0.010693341493606567,
#   -3.694349004490505e-08,
#   0.004652659874409437,
#   0.012399211525917053,
#   0.07299663871526718,
#   -0.07333861291408539,
#   0.050558798015117645,
#   0.003621788928285241,
#   -0.04840917885303497,
#   0.06456565111875534,
#   -0.05688776820898056,
#   0.031297165900468826,
#   0.04466388002038002,
#   0.029897073283791542,
#   -0.026696136221289635,
#   0.08125929534435272,
#   0.06884036958217621,
#   -0.002144386526197195,
#   0.007300528697669506,
#   -0.043683335185050964,
#   0.00727030960842967,
#   0.12200947850942612,
#   -0.022599412128329277,
#   -0.08678086847066879,
#   -0.007723772432655096,
#   -0.04215831682085991,
#   0.01798306219279766,
#   -0.08774631470441818,
#   -0.03180740401148796,
#   0.00958102848380804,
#   -0.035344526171684265,
#   0.005058664828538895,
#   -0.015772635117173195,
#   0.08287037909030914,
#   -0.0233946293592453,
#   -0.0014434837503358722,
#   0.103306844830513,
#   0.01067305076867342,
#   -0.08474132418632507,
#   -0.038107119500637054,
#   0.05071862041950226,
#   0.010972626507282257,
#   0.048292987048625946,
#   -0.010830973275005817,
#   -0.06653600186109543,
#   0.07224473357200623,
#   0.05056401714682579,
#   -0.013620850630104542,
#   0.07223741710186005,
#   -0.06875408440828323,
#   -0.008813728578388691,
#   -0.043118853121995926,
#   -0.12324079126119614,
#   0.012843146920204163,
#   -0.0017839326756075025,
#   -0.01589175872504711,
#   -0.016638005152344704,
#   -0.010464115999639034,
#   0.010803782381117344,
#   -0.02057987079024315,
#   0.05613381043076515,
#   0.03291351720690727,
#   0.09263873845338821,
#   0.020504720509052277,
#   -0.015020662918686867,
#   0.007545856758952141]}

# %%
# Output embeddings to docVectors.json file
with open("output/docVectors.json", "w") as f:
    json.dump(input_data, f)
