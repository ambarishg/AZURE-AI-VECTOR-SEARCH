# %%
# %pip install -r requirements.txt
# Out:
# ...
#
#   Using cached pypdf2-3.0.1-py3-none-any.whl (232 kB)
# ...
#   Using cached sentence_transformers-2.2.2-py3-none-any.whl
# ...
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# ...
#   Obtaining dependency information for azure-search-documents from https://files.pythonhosted.org/packages/a7/c4/d6d91c09b706400d1a2c67bcb78335d45368c83562e3531e8157a49843d8/azure_search_documents-11.4.0-py3-none-any.whl.metadata
#   Using cached azure_search_documents-11.4.0-py3-none-any.whl.metadata (22 kB)
# ...
#   Obtaining dependency information for transformers<5.0.0,>=4.6.0 from https://files.pythonhosted.org/packages/20/0a/739426a81f7635b422fbe6cb8d1d99d1235579a6ac8024c13d743efa6847/transformers-4.36.2-py3-none-any.whl.metadata
#   Using cached transformers-4.36.2-py3-none-any.whl.metadata (126 kB)
# ...
#   Obtaining dependency information for tqdm from https://files.pythonhosted.org/packages/00/e5/f12a80907d0884e6dff9c16d0c0114d81b8cd07dc3ae54c5e962cc83037e/tqdm-4.66.1-py3-none-any.whl.metadata
# ...
